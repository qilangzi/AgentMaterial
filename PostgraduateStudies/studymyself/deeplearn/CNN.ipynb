# %% [markdown]
# # 卷积神经网络
# ![](../img/img_18.png)
# ![](../img/img_19.png)
# - 卷积为e.g.6表示filter6次得到6个特征，然后这6个特征再进行下一次卷积（10），得到新的（10）特征，最后进行全连接，得到结果
# - 步长
# - ![](../img/img_20.png)
# - 卷积核尺寸：卷积核的尺寸为卷积核的宽和高，卷积核的宽和高一般为奇数
# - 边界填充：填充边界，使得数据原来的边界点重复利用，避免边界点丢失
# - 卷积核个数：一般为特征图的数量
# - ![](../img/img_21.png)
# - Vgg
# - ![](../img/img_22.png)
# - Resnet
#     - 残差网络随着神经网络层数增加，准确率会提高（对模型有促进的层选用，否则舍弃）（50或者101层经典直接用）
# - 感受野
#     - 神经网络中，某一层的单个神经元所能 “看见”（即依赖、响应）的输入数据（通常是原始输入，如图像的像素区域）的空间范围。
# - RNN递归神经网络
#     - 比如特征与时间有相关性，需要考虑时间序列
#     - 将所有时间序列特征都保留下来
#     - ![](../img/img_23.png)
# - LSTM
#     - 三个门控机制（输入门、遗忘门、输出门），专门解决长期依赖问题，通过添加关键参数C决定什么该被遗忘
#     - ![](../img/img_24.png)
#     -
